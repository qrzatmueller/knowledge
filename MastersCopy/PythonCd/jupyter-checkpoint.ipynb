# %%
import sympy as sp

# Define symbols
A, Omega, g, x = sp.symbols('A Omega g x', complex=True)

# Define the cubic equation in terms of x (where x = k^2)
cubic_eq = x**3 - A*x**2 - Omega**2*x + Omega**2*g

# Solve for x symbolically
x_roots = sp.solve(cubic_eq, x)

# Compute k values (square roots of x)
k_roots = []
for x_i in x_roots:
    sqrt_xi = sp.sqrt(x_i)  # Principal square root
    k_roots.append(sqrt_xi)
    k_roots.append(-sqrt_xi)  # Include negative sqrt

# Display results in a readable format
sp.init_printing()  # For better display in Jupyter Notebook

print("Roots of k (symbolic):")
for i, k in enumerate(k_roots):
    display(sp.simplify(k))  # Simplify and display each root
# Out:
# Roots of k (symbolic):
#               ________________________________________________________________
#              ╱
#             ╱
#            ╱                                             3 ___ ⎛ 2      2⎞
#           ╱                                            2⋅╲╱ 2 ⋅⎝A  + 3⋅Ω ⎠
# √6⋅      ╱     2⋅A - ─────────────────────────────────────────────────────────
#         ╱                 ____________________________________________________
#        ╱                 ╱                                 ___________________
#       ╱                 ╱                                 ╱                3
#      ╱               3 ╱        3        2       2       ╱      ⎛ 2      2⎞
#    ╲╱                ╲╱    - 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝A  + 3⋅Ω ⎠  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                             __________________________________
#                                            ╱                                 _
#                                           ╱                                 ╱
#                                    2/3 3 ╱        3        2       2       ╱
# ─────────────────────────────── - 2   ⋅╲╱    - 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱
# _______________________________
# ______________________________
#                             2
#  ⎛     3        2       2  ⎞
#  ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
# ──────────────────────────────────────────────────────────────────────────────
#                         6
#
# __________________________________________________
# _________________________________________________
# ________________________________________________
#                3                              2
#     ⎛ 2      2⎞    ⎛     3        2       2  ⎞
# - 4⋅⎝A  + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
#
#
#
#
#
# ──────────────────────────────────────────────────
#                _______________________________________________________________
#               ╱
#              ╱
#             ╱                                             3 ___ ⎛ 2      2⎞
#            ╱                                            2⋅╲╱ 2 ⋅⎝A  + 3⋅Ω ⎠
# -√6⋅      ╱     2⋅A - ────────────────────────────────────────────────────────
#          ╱                 ___________________________________________________
#         ╱                 ╱                                 __________________
#        ╱                 ╱                                 ╱                3
#       ╱               3 ╱        3        2       2       ╱      ⎛ 2      2⎞
#     ╲╱                ╲╱    - 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝A  + 3⋅Ω ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                              _________________________________
#                                             ╱
#                                            ╱                                 ╱
#                                     2/3 3 ╱        3        2       2       ╱
# ──────────────────────────────── - 2   ⋅╲╱    - 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱
# ________________________________
# _______________________________
#                              2
#   ⎛     3        2       2  ⎞
# + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
# ──────────────────────────────────────────────────────────────────────────────
#                          6
#
# ___________________________________________________
# __________________________________________________
# _________________________________________________
#                 3                              2
#      ⎛ 2      2⎞    ⎛     3        2       2  ⎞
#  - 4⋅⎝A  + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
#
#
#
#
#
# ────────────────────────────────────────────────────
#               ________________________________________________________________
#              ╱
#             ╱
#            ╱                                                   3 ___ ⎛ 2
#           ╱                                                  8⋅╲╱ 2 ⋅⎝A  + 3⋅Ω
# √3⋅      ╱     4⋅A + ─────────────────────────────────────────────────────────
#         ╱                            _________________________________________
#        ╱                            ╱                                 ________
#       ╱                            ╱                                 ╱
#      ╱                          3 ╱        3        2       2       ╱      ⎛ 2
#    ╲╱                (1 + √3⋅ⅈ)⋅╲╱    - 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝A
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                   ____________
#                                                                  ╱
# 2⎞                                                              ╱
#  ⎠                                            2/3            3 ╱        3
# ────────────────────────────────────────── + 2   ⋅(1 + √3⋅ⅈ)⋅╲╱    - 2⋅A  - 9⋅
# __________________________________________
# _________________________________________
#         3                              2
#       2⎞    ⎛     3        2       2  ⎞
#  + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                    6
#
# ________________________________________________________________________
# _______________________________________________________________________
#                      _________________________________________________
#                     ╱                3                              2
#    2       2       ╱      ⎛ 2      2⎞    ⎛     3        2       2  ⎞
# A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝A  + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
#
#
#
#
#
# ────────────────────────────────────────────────────────────────────────
#                _______________________________________________________________
#               ╱
#              ╱
#             ╱                                                   3 ___ ⎛ 2
#            ╱                                                  8⋅╲╱ 2 ⋅⎝A  + 3⋅
# -√3⋅      ╱     4⋅A + ────────────────────────────────────────────────────────
#          ╱                            ________________________________________
#         ╱                            ╱                                 _______
#        ╱                            ╱                                 ╱
#       ╱                          3 ╱        3        2       2       ╱      ⎛
#     ╲╱                (1 + √3⋅ⅈ)⋅╲╱    - 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝A
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                    ___________
#                                                                   ╱
#  2⎞                                                              ╱
# Ω ⎠                                            2/3            3 ╱        3
# ─────────────────────────────────────────── + 2   ⋅(1 + √3⋅ⅈ)⋅╲╱    - 2⋅A  - 9
# ___________________________________________
# __________________________________________
#          3                              2
# 2      2⎞    ⎛     3        2       2  ⎞
#   + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                     6
#
# _________________________________________________________________________
# ________________________________________________________________________
#                       _________________________________________________
#                      ╱                3                              2
#     2       2       ╱      ⎛ 2      2⎞    ⎛     3        2       2  ⎞
# ⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝A  + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────
#               ________________________________________________________________
#              ╱
#             ╱
#            ╱                                                   3 ___ ⎛ 2
#           ╱                                                  8⋅╲╱ 2 ⋅⎝A  + 3⋅Ω
# √3⋅      ╱     4⋅A - ─────────────────────────────────────────────────────────
#         ╱                             ________________________________________
#        ╱                             ╱                                 _______
#       ╱                             ╱                                 ╱
#      ╱                           3 ╱        3        2       2       ╱      ⎛
#    ╲╱                (-1 + √3⋅ⅈ)⋅╲╱    - 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝A
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                     __________
#                                                                    ╱
# 2⎞                                                                ╱
#  ⎠                                             2/3             3 ╱        3
# ─────────────────────────────────────────── - 2   ⋅(-1 + √3⋅ⅈ)⋅╲╱    - 2⋅A  -
# ___________________________________________
# __________________________________________
#          3                              2
# 2      2⎞    ⎛     3        2       2  ⎞
#   + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                     6
#
# __________________________________________________________________________
# _________________________________________________________________________
#                        _________________________________________________
#                       ╱                3                              2
#      2       2       ╱      ⎛ 2      2⎞    ⎛     3        2       2  ⎞
# 9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝A  + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────
#                _______________________________________________________________
#               ╱
#              ╱
#             ╱                                                   3 ___ ⎛ 2
#            ╱                                                  8⋅╲╱ 2 ⋅⎝A  + 3⋅
# -√3⋅      ╱     4⋅A - ────────────────────────────────────────────────────────
#          ╱                             _______________________________________
#         ╱                             ╱                                 ______
#        ╱                             ╱                                 ╱
#       ╱                           3 ╱        3        2       2       ╱      ⎛
#     ╲╱                (-1 + √3⋅ⅈ)⋅╲╱    - 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                      _________
#                                                                     ╱
#  2⎞                                                                ╱
# Ω ⎠                                             2/3             3 ╱        3
# ──────────────────────────────────────────── - 2   ⋅(-1 + √3⋅ⅈ)⋅╲╱    - 2⋅A  -
# ____________________________________________
# ___________________________________________
#           3                              2
#  2      2⎞    ⎛     3        2       2  ⎞
# A  + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                      6
#
# ___________________________________________________________________________
# __________________________________________________________________________
#                         _________________________________________________
#                        ╱                3                              2
#       2       2       ╱      ⎛ 2      2⎞    ⎛     3        2       2  ⎞
#  9⋅A⋅Ω  + 27⋅Ω ⋅g + ╲╱   - 4⋅⎝A  + 3⋅Ω ⎠  + ⎝- 2⋅A  - 9⋅A⋅Ω  + 27⋅Ω ⋅g⎠
#
#
#
#
#
# ────────────────────────────────────────────────────────────────────────────

# %%
import sympy as sp
import numpy as np
# Define inputs
L = 0.1
rho1 = 7850
rho3 = rho1
E1 = 206e9
E3 = E1

rho2 = 2600
eta2 = 0.1
G2 = 0.98e10

b = 0.05 #this is not given in the paper. check if it affects anything. 
h1 = 0.003 / 2
h2 = 0.005 /2
h3 = 0.008 / 2

# Calculate parameters
I1 = b*(h1*2)**3 / 12
I3 = b*(h3*2)**3 / 12
A1 = b*h1*2
A2 = b*h2*2
A3 = b*h3*2

D = E1*I1+E3*I3
m = rho1*A1 + rho2*A2 + rho3*A3 # mass per unit length of beam
t0 = np.sqrt(m*L**4/D)
G2_ = G2*(1+1j*eta2)
g_ = (G2*A2*L**2 / 4/h2**2) * ((E1*A1+E3*A3)/(E1*A1*E3*A3))
g = g_.real
c = 2*h2 + h1+ h3 
Y = c**2/D * ((E1*A1*E3*A3)/(E1*A1+E3*A3))

# Define symbols
A, Omega, g, x = sp.symbols('A Omega g x', complex=True)

# Define the cubic equation
cubic_eq = x**3 - A*x**2 - Omega**2*x + Omega**2*g

# Solve for x symbolically
x_roots = sp.solve(cubic_eq, x)

# Compute k values (square roots of x)
k_roots = []
for x_i in x_roots:
    sqrt_xi = sp.sqrt(x_i)  # Principal square root
    k_roots.append(sqrt_xi)
    k_roots.append(-sqrt_xi)  # Include negative sqrt

# Substitute values for A, Omega, and g
A_value = g_*(1+ Y) 
g_value = g_

# Create substitutions dictionary
subs_dict = {A: A_value, g: g_value}

# Compute numerical values for k
numerical_k = [k.subs(subs_dict).evalf() for k in k_roots]

# Display results
sp.init_printing()  # For better formatting in Jupyter

print("Numerical Roots of k:")
for i, k in enumerate(numerical_k):
    display(k)  # Show each substituted root
# Out:
# Numerical Roots of k:
#
#                  ⎛
#                  ⎜                                                  ⎛
#                  ⎜                                                  ⎜
#                  ⎜                      ⎛     2                   ⎞ ⎜
# 9.61158485886008⋅⎝- 1.30189953583668e-5⋅⎝3.0⋅Ω  + 76810.8423479346⎠⋅⎝- 3.09306
#
#
#
#
#                   ⎛                                    2
#               2   ⎜    ⎛                       2      ⎞    ⎛
# 950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω  - 1.0⎠  - ⎝3.90569860751002e-
#
#
#                        -0.333333333333333
#              0.5      ⎞                         ⎛
#            3⎞         ⎟                         ⎜                           ⎛
#    2      ⎞ ⎟         ⎟                         ⎜                       2   ⎜
# 5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                   - 1.0⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝1
#
#
#
#                                                                        0.5
#                                    2                                 3⎞
#    ⎛                       2      ⎞    ⎛                     2      ⎞ ⎟
# .0⋅⎝- 3.09306950841821e-5⋅Ω  - 1.0⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    - 1
#
#                            0.5
#    0.333333333333333      ⎞
#   ⎞                       ⎟
#   ⎟                       ⎟
#   ⎟                       ⎟
# .0⎠                  + 1.0⎠
#
#                   ⎛
#                   ⎜                                                  ⎛
#                   ⎜                                                  ⎜
#                   ⎜                      ⎛     2                   ⎞ ⎜
# -9.61158485886008⋅⎝- 1.30189953583668e-5⋅⎝3.0⋅Ω  + 76810.8423479346⎠⋅⎝- 3.0930
#
#
#
#
#                    ⎛                                    2
#                2   ⎜    ⎛                       2      ⎞    ⎛
# 6950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω  - 1.0⎠  - ⎝3.90569860751002e
#
#
#                         -0.333333333333333
#               0.5      ⎞                         ⎛
#             3⎞         ⎟                         ⎜                           ⎛
#     2      ⎞ ⎟         ⎟                         ⎜                       2   ⎜
# -5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                   - 1.0⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝
#
#
#
#                                                                         0.5
#                                     2                                 3⎞
#     ⎛                       2      ⎞    ⎛                     2      ⎞ ⎟
# 1.0⋅⎝- 3.09306950841821e-5⋅Ω  - 1.0⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    -
#
#                             0.5
#     0.333333333333333      ⎞
#    ⎞                       ⎟
#    ⎟                       ⎟
#    ⎟                       ⎟
# 1.0⎠                  + 1.0⎠
#
#                  ⎛
#                  ⎜
#                  ⎜
#                  ⎜                                              ⎛     2
# 9.61158485886008⋅⎝(6.50949767918338e-6 - 1.12747807120973e-5⋅ⅈ)⋅⎝3.0⋅Ω  + 7681
#
#
#
#               ⎛
#               ⎜                           ⎛
#             ⎞ ⎜                       2   ⎜    ⎛                       2
# 0.8423479346⎠⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω  - 1.0
#
#
#                                                -0.333333333333333
#                                      0.5      ⎞
#  2                                 3⎞         ⎟
# ⎞    ⎛                     2      ⎞ ⎟         ⎟
# ⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                   + (0.5 + 0.8
#
#
#
#                   ⎛
#                   ⎜                           ⎛
#                   ⎜                       2   ⎜    ⎛                       2
# 66025403784438⋅ⅈ)⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω  -
#
#                                                                            0.5
#                                                    0.333333333333333      ⎞
#                                          0.5      ⎞                       ⎟
#      2                                 3⎞         ⎟                       ⎟
#     ⎞    ⎛                     2      ⎞ ⎟         ⎟                       ⎟
#  1.0⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                  + 1.0⎠
#
#                   ⎛
#                   ⎜
#                   ⎜
#                   ⎜                                              ⎛     2
# -9.61158485886008⋅⎝(6.50949767918338e-6 - 1.12747807120973e-5⋅ⅈ)⋅⎝3.0⋅Ω  + 768
#
#
#
#                ⎛
#                ⎜                           ⎛
#              ⎞ ⎜                       2   ⎜    ⎛                       2
# 10.8423479346⎠⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω  - 1.
#
#
#                                                 -0.333333333333333
#                                       0.5      ⎞
#   2                                 3⎞         ⎟
#  ⎞    ⎛                     2      ⎞ ⎟         ⎟
# 0⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                   + (0.5 + 0.
#
#
#
#                    ⎛
#                    ⎜                           ⎛
#                    ⎜                       2   ⎜    ⎛                       2
# 866025403784438⋅ⅈ)⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω
#
#                                                                             0.
#                                                     0.333333333333333      ⎞
#                                           0.5      ⎞                       ⎟
#       2                                 3⎞         ⎟                       ⎟
#      ⎞    ⎛                     2      ⎞ ⎟         ⎟                       ⎟
# - 1.0⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                  + 1.0⎠
#
# 5
#
#                  ⎛
#                  ⎜
#                  ⎜
#                  ⎜                                              ⎛     2
# 9.61158485886008⋅⎝(6.50949767918338e-6 + 1.12747807120973e-5⋅ⅈ)⋅⎝3.0⋅Ω  + 7681
#
#
#
#               ⎛
#               ⎜                           ⎛
#             ⎞ ⎜                       2   ⎜    ⎛                       2
# 0.8423479346⎠⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω  - 1.0
#
#
#                                                -0.333333333333333
#                                      0.5      ⎞
#  2                                 3⎞         ⎟
# ⎞    ⎛                     2      ⎞ ⎟         ⎟
# ⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                   + (0.5 - 0.8
#
#
#
#                   ⎛
#                   ⎜                           ⎛
#                   ⎜                       2   ⎜    ⎛                       2
# 66025403784438⋅ⅈ)⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω  -
#
#                                                                            0.5
#                                                    0.333333333333333      ⎞
#                                          0.5      ⎞                       ⎟
#      2                                 3⎞         ⎟                       ⎟
#     ⎞    ⎛                     2      ⎞ ⎟         ⎟                       ⎟
#  1.0⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                  + 1.0⎠
#
#                   ⎛
#                   ⎜
#                   ⎜
#                   ⎜                                              ⎛     2
# -9.61158485886008⋅⎝(6.50949767918338e-6 + 1.12747807120973e-5⋅ⅈ)⋅⎝3.0⋅Ω  + 768
#
#
#
#                ⎛
#                ⎜                           ⎛
#              ⎞ ⎜                       2   ⎜    ⎛                       2
# 10.8423479346⎠⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω  - 1.
#
#
#                                                 -0.333333333333333
#                                       0.5      ⎞
#   2                                 3⎞         ⎟
#  ⎞    ⎛                     2      ⎞ ⎟         ⎟
# 0⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                   + (0.5 - 0.
#
#
#
#                    ⎛
#                    ⎜                           ⎛
#                    ⎜                       2   ⎜    ⎛                       2
# 866025403784438⋅ⅈ)⋅⎝- 3.09306950841821e-5⋅Ω  + ⎝1.0⋅⎝- 3.09306950841821e-5⋅Ω
#
#                                                                             0.
#                                                     0.333333333333333      ⎞
#                                           0.5      ⎞                       ⎟
#       2                                 3⎞         ⎟                       ⎟
#      ⎞    ⎛                     2      ⎞ ⎟         ⎟                       ⎟
# - 1.0⎠  - ⎝3.90569860751002e-5⋅Ω  + 1.0⎠ ⎠    - 1.0⎠                  + 1.0⎠
#
# 5
